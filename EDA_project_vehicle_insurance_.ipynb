# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjaykumar-singh/EDA-OF-Vehicle-insurance/blob/main/EDA_project_vehicle_insurance_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # VEHICLES BIGDATA

# %%
df=pd.read_csv("VehiclesBig.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Accident_Index                    59999 non-null  float64
#  1   Vehicle_Reference                 59999 non-null  float64
#  2   Vehicle_Type                      59999 non-null  float64
#  3   Towing_and_Articulation           59999 non-null  float64
#  4   Vehicle_Manoeuvre                 59999 non-null  float64
#  5   Vehicle_Location-Restricted_Lane  59999 non-null  float64
#  6   Junction_Location                 59999 non-null  float64
#  7   Skidding_and_Overturning          59999 non-null  float64
#  8   Hit_Object_in_Carriageway         59999 non-null  float64
#  9   Vehicle_Leaving_Carriageway       59999 non-null  float64
#  10  Hit_Object_off_Carriageway        59999 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Accident_Index                      988576
# Vehicle_Reference                   988576
# Vehicle_Type                        988576
# Towing_and_Articulation             988576
# Vehicle_Manoeuvre                   988576
# Vehicle_Location-Restricted_Lane    988576
# Junction_Location                   988576
# Skidding_and_Overturning            988576
# Hit_Object_in_Carriageway           988576
# Vehicle_Leaving_Carriageway         988576
# Hit_Object_off_Carriageway          988576
# 1st_Point_of_Impact                 988576
# Was_Vehicle_Left_Hand_Drive?        988576
# Journey_Purpose_of_Driver           988576
# Sex_of_Driver                       988576
# Age_of_Driver                       988576
# Age_Band_of_Driver                  988576
# Engine_Capacity_(CC)                988576
# Propulsion_Code                     988576
# Age_of_Vehicle                      988576
# Driver_IMD_Decile                   988576
# Driver_Home_Area_Type               988576
# ...

# %%
df.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574    False
# Length: 1048575, dtype: bool

# %%
df1=df.drop_duplicates()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60000 entries, 0 to 1048574
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Accident_Index                    59999 non-null  float64
#  1   Vehicle_Reference                 59999 non-null  float64
#  2   Vehicle_Type                      59999 non-null  float64
#  3   Towing_and_Articulation           59999 non-null  float64
#  4   Vehicle_Manoeuvre                 59999 non-null  float64
#  5   Vehicle_Location-Restricted_Lane  59999 non-null  float64
#  6   Junction_Location                 59999 non-null  float64
#  7   Skidding_and_Overturning          59999 non-null  float64
#  8   Hit_Object_in_Carriageway         59999 non-null  float64
#  9   Vehicle_Leaving_Carriageway       59999 non-null  float64
#  10  Hit_Object_off_Carriageway        59999 non-null  float64
# ...

# %%
df1.isnull().sum()
# Out:
# Accident_Index                      1
# Vehicle_Reference                   1
# Vehicle_Type                        1
# Towing_and_Articulation             1
# Vehicle_Manoeuvre                   1
# Vehicle_Location-Restricted_Lane    1
# Junction_Location                   1
# Skidding_and_Overturning            1
# Hit_Object_in_Carriageway           1
# Vehicle_Leaving_Carriageway         1
# Hit_Object_off_Carriageway          1
# 1st_Point_of_Impact                 1
# Was_Vehicle_Left_Hand_Drive?        1
# Journey_Purpose_of_Driver           1
# Sex_of_Driver                       1
# Age_of_Driver                       1
# Age_Band_of_Driver                  1
# Engine_Capacity_(CC)                1
# Propulsion_Code                     1
# Age_of_Vehicle                      1
# Driver_IMD_Decile                   1
# Driver_Home_Area_Type               1
# dtype: int64

# %%
df2= df1.drop(59998)

# %%
# Save to CS
df.to_csv('cleaned_data_1.csv', index=False)

# %%
df2.isnull().sum()
# Out:
# Accident_Index                      0
# Vehicle_Reference                   0
# Vehicle_Type                        0
# Towing_and_Articulation             0
# Vehicle_Manoeuvre                   0
# Vehicle_Location-Restricted_Lane    0
# Junction_Location                   0
# Skidding_and_Overturning            0
# Hit_Object_in_Carriageway           0
# Vehicle_Leaving_Carriageway         0
# Hit_Object_off_Carriageway          0
# 1st_Point_of_Impact                 0
# Was_Vehicle_Left_Hand_Drive?        0
# Journey_Purpose_of_Driver           0
# Sex_of_Driver                       0
# Age_of_Driver                       0
# Age_Band_of_Driver                  0
# Engine_Capacity_(CC)                0
# Propulsion_Code                     0
# Age_of_Vehicle                      0
# Driver_IMD_Decile                   0
# Driver_Home_Area_Type               0
# dtype: int64

# %%
df2.describe()
# Out:
#        Accident_Index  Vehicle_Reference  Vehicle_Type  \
# count    5.999900e+04       59999.000000  59999.000000
# mean     3.353056e+07           1.526775      9.151403
# std      8.205859e+09           0.679849      6.567517
# min      1.000000e+00           1.000000     -1.000000
# 25%      1.500050e+04           1.000000      9.000000
# 50%      3.000000e+04           1.000000      9.000000
# 75%      4.499950e+04           2.000000      9.000000
# max      2.010000e+12          13.000000     90.000000
#
#        Towing_and_Articulation  Vehicle_Manoeuvre  \
# count             59999.000000       59999.000000
# mean                  0.015867          12.745262
# std                   0.224462           6.103481
# min                  -1.000000          -1.000000
# 25%                   0.000000           7.000000
# 50%                   0.000000          17.000000
# 75%                   0.000000          18.000000
# max                   5.000000          18.000000
#
# ...

# %%
corr_matrix = df2.select_dtypes(include=['number']).corr()
corr_matrix
# Out:
#                                   Accident_Index  Vehicle_Reference  \
# Accident_Index                          1.000000          -0.003163
# Vehicle_Reference                      -0.003163           1.000000
# Vehicle_Type                           -0.000094           0.028571
# Towing_and_Articulation                -0.000289           0.002459
# Vehicle_Manoeuvre                      -0.005181          -0.080792
# Vehicle_Location-Restricted_Lane        0.058225          -0.003292
# Junction_Location                       0.003356          -0.011249
# Skidding_and_Overturning               -0.000802          -0.058797
# Hit_Object_in_Carriageway              -0.000825          -0.081235
# Vehicle_Leaving_Carriageway            -0.000739          -0.075057
# Hit_Object_off_Carriageway             -0.000760          -0.077882
# 1st_Point_of_Impact                     0.007328          -0.011158
# Was_Vehicle_Left_Hand_Drive?            0.000867          -0.021137
# ...

# %%
plt.figure(figsize=(30,30))
sns.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for column in df2.columns:
    plt.figure(figsize=(8, 5))
    plt.hist(df2[column], bins=30, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# %%
from pandas_profiling import ProfileReport
report=ProfileReport(df2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-1475ebcc7cf3> in <cell line: 0>()
# ----> 1 from pandas_profiling import ProfileReport
#       2 report=ProfileReport(df2)
#
# ModuleNotFoundError: No module named 'pandas_profiling'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import webbrowser

file_path = "report.html"
webbrowser.open(file_path)
# Out:
# False

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # CASUALTIES BIGDATA

# %%
df3=pd.read_csv("CasualtiesBig.csv")

# %%
df3.to_csv("CasualtiesBig__.csv")

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59998 entries, 0 to 59997
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Accident_Index                      59998 non-null  int64
#  1   Vehicle_Reference                   59998 non-null  int64
#  2   Casualty_Reference                  59998 non-null  int64
#  3   Casualty_Class                      59998 non-null  int64
#  4   Sex_of_Casualty                     59998 non-null  int64
#  5   Age_of_Casualty                     59998 non-null  int64
#  6   Age_Band_of_Casualty                59998 non-null  int64
#  7   Casualty_Severity                   59998 non-null  int64
#  8   Pedestrian_Location                 59998 non-null  int64
#  9   Pedestrian_Movement                 59998 non-null  int64
#  10  Car_Passenger                       59998 non-null  int64
# ...

# %%
df3.isnull().sum()
# Out:
# Accident_Index                        0
# Vehicle_Reference                     0
# Casualty_Reference                    0
# Casualty_Class                        0
# Sex_of_Casualty                       0
# Age_of_Casualty                       0
# Age_Band_of_Casualty                  0
# Casualty_Severity                     0
# Pedestrian_Location                   0
# Pedestrian_Movement                   0
# Car_Passenger                         0
# Bus_or_Coach_Passenger                0
# Pedestrian_Road_Maintenance_Worker    0
# Casualty_Type                         0
# Casualty_Home_Area_Type               0
# dtype: int64

# %%
df3.describe()
# Out:
#        Accident_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# count    59998.000000       59998.000000        59998.000000    59998.000000
# mean     29999.500000           1.397297            1.351495        1.580736
# std      17320.075062           0.576247            0.858667        0.760265
# min          1.000000           1.000000            1.000000        1.000000
# 25%      15000.250000           1.000000            1.000000        1.000000
# 50%      29999.500000           1.000000            1.000000        1.000000
# 75%      44998.750000           2.000000            1.000000        2.000000
# max      59998.000000          12.000000           23.000000        3.000000
#
#        Sex_of_Casualty  Age_of_Casualty  Age_Band_of_Casualty  \
# count     59998.000000     59998.000000          59998.000000
# mean          1.401780        32.467949              5.741825
# std           0.490568        18.570679              2.547752
# ...

# %%
from pandas_profiling import ProfileReport
report=ProfileReport(df2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-1475ebcc7cf3> in <cell line: 0>()
# ----> 1 from pandas_profiling import ProfileReport
#       2 report=ProfileReport(df2)
#
# ModuleNotFoundError: No module named 'pandas_profiling'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import webbrowser

file_path = "report.html"
webbrowser.open(file_path)
# Out:
# False

# %%
df3.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 59993    False
# 59994    False
# 59995    False
# 59996    False
# 59997    False
# Length: 59998, dtype: bool

# %%
correlation_matrix = df3.corr(numeric_only=True)
correlation_matrix
# Out:
#                                     Accident_Index  Vehicle_Reference  \
# Accident_Index                            1.000000           0.184748
# Vehicle_Reference                         0.184748           1.000000
# Casualty_Reference                        0.141952           0.236786
# Casualty_Class                           -0.010958          -0.268826
# Sex_of_Casualty                           0.053801           0.019443
# Age_of_Casualty                           0.018822           0.049180
# Age_Band_of_Casualty                      0.037518           0.064679
# Casualty_Severity                         0.009585           0.079487
# Pedestrian_Location                      -0.036176          -0.264712
# Pedestrian_Movement                      -0.041199          -0.213420
# Car_Passenger                             0.130075           0.078255
# Bus_or_Coach_Passenger                   -0.042335          -0.059742
# ...

# %%
correlation_matrix = df3.select_dtypes(include=['number']).corr()
print(correlation_matrix)
# Out:
#                                     Accident_Index  Vehicle_Reference  \
# Accident_Index                            1.000000           0.184748
# Vehicle_Reference                         0.184748           1.000000
# Casualty_Reference                        0.141952           0.236786
# Casualty_Class                           -0.010958          -0.268826
# Sex_of_Casualty                           0.053801           0.019443
# Age_of_Casualty                           0.018822           0.049180
# Age_Band_of_Casualty                      0.037518           0.064679
# Casualty_Severity                         0.009585           0.079487
# Pedestrian_Location                      -0.036176          -0.264712
# Pedestrian_Movement                      -0.041199          -0.213420
# Car_Passenger                             0.130075           0.078255
# Bus_or_Coach_Passenger                   -0.042335          -0.059742
# ...

# %%
df3.head()
# Out:
#    Accident_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0               1                  1                   1               3
# 1               2                  1                   1               2
# 2               3                  2                   1               1
# 3               4                  1                   1               3
# 4               5                  1                   1               1
#
#    Sex_of_Casualty  Age_of_Casualty  Age_Band_of_Casualty  Casualty_Severity  \
# 0                1               37                     7                  2
# 1                1               37                     7                  3
# 2                1               62                     9                  3
# 3                1               30                     6                  3
# 4                1               49                     8                  3
#
#    Pedestrian_Location  Pedestrian_Movement  Car_Passenger  \
# ...

# %%
df3['Sex_of_Casualty'].value_counts()
# Out:
# Sex_of_Casualty
#  1    35883
#  2    24112
# -1        3
# Name: count, dtype: int64

# %%
df3['Sex_of_Casualty'].value_counts().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    figsize=(6, 6) )
plt.title('Distribution of Sex of Casualty')
plt.ylabel('')  # Remove y-axis label
plt.show()

# %%
df3['Casualty_Class'].value_counts().plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    figsize=(6, 6) )
plt.title('Distribution of Casualty_Class')
plt.ylabel('')  # Remove y-axis label
plt.show()

# %%
# age_counts = df3['Age_of_Casualty'].value_counts()
# plt.bar(age_counts.index, age_counts.values, color='skyblue')
# plt.title('Distribution of Age of Casualty')
# plt.xlabel('Age of Casualty')
# plt.ylabel('Frequency')
# plt.show()

# %%
plt.hist(df3['Age_of_Casualty'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Age of Casualty')
plt.xlabel('Age of Casualty')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
df4=df3.drop(columns='Pedestrian_Road_Maintenance_Worker')

# %%
corr=df4.corr(numeric_only=True)
corr
# Out:
#                          Accident_Index  Vehicle_Reference  \
# Accident_Index                 1.000000           0.184748
# Vehicle_Reference              0.184748           1.000000
# Casualty_Reference             0.141952           0.236786
# Casualty_Class                -0.010958          -0.268826
# Sex_of_Casualty                0.053801           0.019443
# Age_of_Casualty                0.018822           0.049180
# Age_Band_of_Casualty           0.037518           0.064679
# Casualty_Severity              0.009585           0.079487
# Pedestrian_Location           -0.036176          -0.264712
# Pedestrian_Movement           -0.041199          -0.213420
# Car_Passenger                  0.130075           0.078255
# Bus_or_Coach_Passenger        -0.042335          -0.059742
# Casualty_Type                  0.109393           0.124546
# Casualty_Home_Area_Type        0.054526           0.058468
#
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(corr,annot=True)
plt.savefig('heatmap.png', dpi=300, bbox_inches='tight')  # Saves as PNG
plt.show()
